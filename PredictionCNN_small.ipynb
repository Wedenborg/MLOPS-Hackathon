# %%
# !pip install carbontracker
# !pip install codecarbon
# Out:
# Collecting carbontracker
#   Downloading carbontracker-2.3.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from carbontracker) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from carbontracker) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from carbontracker) (2.2.2)
# Requirement already satisfied: geocoder in /usr/local/lib/python3.12/dist-packages (from carbontracker) (1.38.1)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.12/dist-packages (from carbontracker) (12.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from carbontracker) (5.9.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from carbontracker) (8.7.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from carbontracker) (9.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from carbontracker) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from carbontracker) (0.13.2)
# Collecting reportlab<4.0.0 (from carbontracker)
#   Downloading reportlab-3.6.13.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 38.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from reportlab<4.0.0->carbontracker) (11.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from geocoder->carbontracker) (8.2.1)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from geocoder->carbontracker) (1.0.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.12/dist-packages (from geocoder->carbontracker) (0.1.6)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from geocoder->carbontracker) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->carbontracker) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->carbontracker) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->carbontracker) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->carbontracker) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->carbontracker) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->carbontracker) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->carbontracker) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->carbontracker) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->carbontracker) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->carbontracker) (2025.2)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pynvml->carbontracker) (12.575.51)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->carbontracker) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->carbontracker) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->carbontracker) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->carbontracker) (2025.8.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ratelim->geocoder->carbontracker) (4.4.2)
# Downloading carbontracker-2.3.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 3.9 MB/s eta 0:00:00
# Building wheels for collected packages: reportlab
#   Building wheel for reportlab (setup.py) ... done
#   Created wheel for reportlab: filename=reportlab-3.6.13-cp312-cp312-linux_x86_64.whl size=2237985 sha256=5da2c59970e860dd0eb43d5086b5294c8cc1f976c7ec4b1d8795d66a80116a24
#   Stored in directory: /root/.cache/pip/wheels/48/67/58/d54706b91458551310cfa11bd10777cb55438c6f33bf3a5292
# Successfully built reportlab
# Installing collected packages: reportlab, carbontracker
# Successfully installed carbontracker-2.3.1 reportlab-3.6.13
# Collecting codecarbon
#   Downloading codecarbon-3.0.4-py3-none-any.whl.metadata (11 kB)
# Collecting arrow (from codecarbon)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from codecarbon) (8.2.1)
# Collecting fief-client[cli] (from codecarbon)
#   Downloading fief_client-0.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from codecarbon) (2.2.2)
# Requirement already satisfied: prometheus_client in /usr/local/lib/python3.12/dist-packages (from codecarbon) (0.22.1)
# Collecting psutil>=6.0.0 (from codecarbon)
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from codecarbon) (2.11.7)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.12/dist-packages (from codecarbon) (12.0.0)
# Collecting rapidfuzz (from codecarbon)
#   Downloading rapidfuzz-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from codecarbon) (2.32.4)
# Collecting questionary (from codecarbon)
#   Downloading questionary-2.1.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from codecarbon) (13.9.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from codecarbon) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from arrow->codecarbon) (2.9.0.post0)
# Collecting types-python-dateutil>=2.8.10 (from arrow->codecarbon)
#   Downloading types_python_dateutil-2.9.0.20250822-py3-none-any.whl.metadata (1.8 kB)
# Collecting httpx<0.28.0,>=0.21.3 (from fief-client[cli]->codecarbon)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jwcrypto<2.0.0,>=1.4 (from fief-client[cli]->codecarbon)
#   Downloading jwcrypto-1.5.6-py3-none-any.whl.metadata (3.1 kB)
# Collecting yaspin (from fief-client[cli]->codecarbon)
#   Downloading yaspin-3.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->codecarbon) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->codecarbon) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->codecarbon) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->codecarbon) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->codecarbon) (0.4.1)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pynvml->codecarbon) (12.575.51)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from questionary->codecarbon) (3.0.51)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->codecarbon) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->codecarbon) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->codecarbon) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->codecarbon) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->codecarbon) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->codecarbon) (2.19.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.9)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.16.0)
# Requirement already satisfied: cryptography>=3.4 in /usr/local/lib/python3.12/dist-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (43.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.17.0)
# Collecting termcolor<2.4.0,>=2.2.0 (from yaspin->fief-client[cli]->codecarbon)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.22)
# Downloading codecarbon-3.0.4-py3-none-any.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.7/277.7 kB 12.2 MB/s eta 0:00:00
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 11.7 MB/s eta 0:00:00
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.7 MB/s eta 0:00:00
# Downloading questionary-2.1.0-py3-none-any.whl (36 kB)
# Downloading rapidfuzz-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 48.3 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.2 MB/s eta 0:00:00
# Downloading jwcrypto-1.5.6-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 4.9 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20250822-py3-none-any.whl (17 kB)
# Downloading fief_client-0.20.0-py3-none-any.whl (20 kB)
# Downloading yaspin-3.1.0-py3-none-any.whl (18 kB)
# Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Installing collected packages: types-python-dateutil, termcolor, rapidfuzz, psutil, yaspin, questionary, httpx, arrow, jwcrypto, fief-client, codecarbon
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.1.0
#     Uninstalling termcolor-3.1.0:
#       Successfully uninstalled termcolor-3.1.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# firebase-admin 6.9.0 requires httpx[http2]==0.28.1, but you have httpx 0.27.2 which is incompatible.
# google-genai 1.30.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# Successfully installed arrow-1.3.0 codecarbon-3.0.4 fief-client-0.20.0 httpx-0.27.2 jwcrypto-1.5.6 psutil-7.0.0 questionary-2.1.0 rapidfuzz-3.13.0 termcolor-2.3.0 types-python-dateutil-2.9.0.20250822 yaspin-3.1.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
import matplotlib

matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
colors = ["#EF476F",  "#06D6A0", "#FFD166", "#073B4C"]


plt.rcParams.update({
    'font.size': 20,
    'axes.labelsize': 20,
    'axes.titlesize': 20,
    'xtick.labelsize': 20,
    'ytick.labelsize': 20,
    'legend.fontsize': 'medium',
})

import wandb
from wandb.integration.keras import WandbCallback


from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

# %%
data_dir = 'data/DailyDelhiClimateTrain.csv'
df = pd.read_csv(data_dir)

# %%
# Initialize a W&B run and set hyperparameters
wandb.login(key="d0443b4249d89fb1ed2dde3aa1dedea814f47c61")
wandb.init(
    project="MLOPS-Hackathon",   # Name of your project
    entity="emiliewedenborg-technical-university-of-denmark",  # Replace with your W&B entity
    name="temperature-forecasting-cnn-smaller",  # Name of the run

    config={
        "epochs": 100,
        "batch_size": 32,
        "learning_rate": 0.001,
        "optimizer": "adam"
    }
)

config = wandb.config
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ask-e-oren (emiliewedenborg-technical-university-of-denmark) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250822_094511-i8ti0l6l</code>
# Syncing run <strong><a href='https://wandb.ai/emiliewedenborg-technical-university-of-denmark/MLOPS-Hackathon/runs/i8ti0l6l' target="_blank">temperature-forecasting-cnn-smaller</a></strong> to <a href='https://wandb.ai/emiliewedenborg-technical-university-of-denmark/MLOPS-Hackathon' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/emiliewedenborg-technical-university-of-denmark/MLOPS-Hackathon' target="_blank">https://wandb.ai/emiliewedenborg-technical-university-of-denmark/MLOPS-Hackathon</a>
#  View run at <a href='https://wandb.ai/emiliewedenborg-technical-university-of-denmark/MLOPS-Hackathon/runs/i8ti0l6l' target="_blank">https://wandb.ai/emiliewedenborg-technical-university-of-denmark/MLOPS-Hackathon/runs/i8ti0l6l</a>

# %% [markdown]
# # Do actual predictions!

# %% [markdown]
# # Predict more than just the temp (multivariate predictions)

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df.set_index('date', inplace= True)

n_cols = 4
cols = list(df.loc[:, ['meantemp', 'humidity', 'wind_speed', 'meanpressure']])
dataset = df[cols]
dataset = pd.DataFrame(dataset)
data = dataset.values

data.shape
# Out:
# (1462, 4)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data))

# %%
train_size = int(len(data) * 0.75)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 1096 Test Size : 366

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (1096, 4)

# %%
# Creating a Training set with 60 time-steps
x_train = []
y_train = []
time_steps = 30
n_cols = 4

for i in range(time_steps, len(train_data)):
    x_train.append(train_data[i-time_steps:i, :n_cols])
    y_train.append(train_data[i, :n_cols])

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))
x_train.shape , y_train.shape
# Out:
# ((1066, 30, 4), (1066, 4))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

model2 = Sequential([
    Conv1D(filters=16, kernel_size=3, activation="relu", input_shape=(x_train.shape[1], n_cols)),
    MaxPooling1D(pool_size=2),
    Conv1D(filters=32, kernel_size=3, activation="relu"),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(16, activation="relu"),
    Dense(n_cols)
])

model2.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
history2 = model2.fit(
    x_train,
    y_train,
    epochs=100,
    batch_size=32,
    callbacks=[WandbCallback(save_graph=False)]
)
# Out:
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.2088 - mean_absolute_error: 0.3848
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0778 - mean_absolute_error: 0.2156
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0427 - mean_absolute_error: 0.1617
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0331 - mean_absolute_error: 0.1416
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0282 - mean_absolute_error: 0.1300
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0258 - mean_absolute_error: 0.1218
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0256 - mean_absolute_error: 0.1229
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0253 - mean_absolute_error: 0.1231
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0222 - mean_absolute_error: 0.1161
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0203 - mean_absolute_error: 0.1109
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0209 - mean_absolute_error: 0.1107
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0179 - mean_absolute_error: 0.1035
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - mean_absolute_error: 0.1036
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - mean_absolute_error: 0.0986
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0162 - mean_absolute_error: 0.0987
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0158 - mean_absolute_error: 0.0960
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0152 - mean_absolute_error: 0.0946
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0161 - mean_absolute_error: 0.0968
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0153 - mean_absolute_error: 0.0936
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0153 - mean_absolute_error: 0.0940
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - mean_absolute_error: 0.0891
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0142 - mean_absolute_error: 0.0898
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 - mean_absolute_error: 0.0870
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - mean_absolute_error: 0.0862
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0834
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0138 - mean_absolute_error: 0.0882
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0121 - mean_absolute_error: 0.0837
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0121 - mean_absolute_error: 0.0843
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0119 - mean_absolute_error: 0.0842
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0124 - mean_absolute_error: 0.0835
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0117 - mean_absolute_error: 0.0814
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0111 - mean_absolute_error: 0.0796
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105 - mean_absolute_error: 0.0782
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0108 - mean_absolute_error: 0.0782
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0115 - mean_absolute_error: 0.0811
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0108 - mean_absolute_error: 0.0786
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0108 - mean_absolute_error: 0.0789
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0109 - mean_absolute_error: 0.0778
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0101 - mean_absolute_error: 0.0756
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0099 - mean_absolute_error: 0.0762
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0105 - mean_absolute_error: 0.0771
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0105 - mean_absolute_error: 0.0779
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0097 - mean_absolute_error: 0.0755
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0097 - mean_absolute_error: 0.0735
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0097 - mean_absolute_error: 0.0745
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0095 - mean_absolute_error: 0.0748
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0717
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0738
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0094 - mean_absolute_error: 0.0737
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - mean_absolute_error: 0.0760
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - mean_absolute_error: 0.0746
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - mean_absolute_error: 0.0744
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0100 - mean_absolute_error: 0.0734
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - mean_absolute_error: 0.0735
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0732
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0095 - mean_absolute_error: 0.0734
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0094 - mean_absolute_error: 0.0725
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0723
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0095 - mean_absolute_error: 0.0737
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0736
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - mean_absolute_error: 0.0713
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - mean_absolute_error: 0.0706
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - mean_absolute_error: 0.0701
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0719
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - mean_absolute_error: 0.0700
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0721
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0081 - mean_absolute_error: 0.0690
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0089 - mean_absolute_error: 0.0697
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093 - mean_absolute_error: 0.0712
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - mean_absolute_error: 0.0698
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - mean_absolute_error: 0.0677
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - mean_absolute_error: 0.0696
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - mean_absolute_error: 0.0709
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - mean_absolute_error: 0.0698
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093 - mean_absolute_error: 0.0715
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0090 - mean_absolute_error: 0.0713
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0080 - mean_absolute_error: 0.0673
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0085 - mean_absolute_error: 0.0689
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0084 - mean_absolute_error: 0.0686
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0087 - mean_absolute_error: 0.0690
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0078 - mean_absolute_error: 0.0670
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0082 - mean_absolute_error: 0.0677
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - mean_absolute_error: 0.0679
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0084 - mean_absolute_error: 0.0684
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084 - mean_absolute_error: 0.0683
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0084 - mean_absolute_error: 0.0684
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0084 - mean_absolute_error: 0.0687
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0080 - mean_absolute_error: 0.0665
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0082 - mean_absolute_error: 0.0678
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - mean_absolute_error: 0.0677
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - mean_absolute_error: 0.0659
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - mean_absolute_error: 0.0662
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - mean_absolute_error: 0.0671
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085 - mean_absolute_error: 0.0680
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - mean_absolute_error: 0.0657
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mean_absolute_error: 0.0645
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - mean_absolute_error: 0.0687
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - mean_absolute_error: 0.0683
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - mean_absolute_error: 0.0653
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - mean_absolute_error: 0.0651

# %%
plt.figure(figsize=(12, 8))
plt.plot(history2.history["loss"])
plt.plot(history2.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
# Creating a testing set with 30 time-steps and 1 output
time_steps = 30
test_data = scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 4

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
x_test.shape , y_test.shape
# Out:
# ((366, 30, 4), (366, 4))

# %%
# Get Prediction
predictions = model2.predict(x_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

# %%
RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4618674.py in <cell line: 0>()
# ----> 1 RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
#       2 RMSE
#
# ValueError: operands could not be broadcast together with shapes (366,4) (0,)

# %%
from datetime import timedelta

# %%
def insert_end(Xin, new_input):
    timestep = 30
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future = 30
forcast = []
Xin = x_test[-1 :, :, :]
time = []
for i in range(0, future):
    out = model2.predict(Xin, batch_size=5)
    forcast.append(out[0])
    print(forcast)
    Xin = insert_end(Xin, out[0, 0])
    time.append(pd.to_datetime(df.index[-1]) + timedelta(days=i))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32), array([0.7104702 , 0.33911332, 0.18204874, 0.5085752 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32), array([0.7104702 , 0.33911332, 0.18204874, 0.5085752 ], dtype=float32), array([0.7125408 , 0.33914858, 0.18116963, 0.49774686], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32), array([0.7104702 , 0.33911332, 0.18204874, 0.5085752 ], dtype=float32), array([0.7125408 , 0.33914858, 0.18116963, 0.49774686], dtype=float32), array([0.70706934, 0.3528981 , 0.1753701 , 0.50134826], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32), array([0.7104702 , 0.33911332, 0.18204874, 0.5085752 ], dtype=float32), array([0.7125408 , 0.33914858, 0.18116963, 0.49774686], dtype=float32), array([0.70706934, 0.3528981 , 0.1753701 , 0.50134826], dtype=float32), array([0.70761764, 0.3546335 , 0.17554677, 0.5129982 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32), array([0.7104702 , 0.33911332, 0.18204874, 0.5085752 ], dtype=float32), array([0.7125408 , 0.33914858, 0.18116963, 0.49774686], dtype=float32), array([0.70706934, 0.3528981 , 0.1753701 , 0.50134826], dtype=float32), array([0.70761764, 0.3546335 , 0.17554677, 0.5129982 ], dtype=float32), array([0.71186775, 0.36758322, 0.1761806 , 0.5247072 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32), array([0.7104702 , 0.33911332, 0.18204874, 0.5085752 ], dtype=float32), array([0.7125408 , 0.33914858, 0.18116963, 0.49774686], dtype=float32), array([0.70706934, 0.3528981 , 0.1753701 , 0.50134826], dtype=float32), array([0.70761764, 0.3546335 , 0.17554677, 0.5129982 ], dtype=float32), array([0.71186775, 0.36758322, 0.1761806 , 0.5247072 ], dtype=float32), array([0.71057916, 0.37134275, 0.17450306, 0.52613425], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32), array([0.7104702 , 0.33911332, 0.18204874, 0.5085752 ], dtype=float32), array([0.7125408 , 0.33914858, 0.18116963, 0.49774686], dtype=float32), array([0.70706934, 0.3528981 , 0.1753701 , 0.50134826], dtype=float32), array([0.70761764, 0.3546335 , 0.17554677, 0.5129982 ], dtype=float32), array([0.71186775, 0.36758322, 0.1761806 , 0.5247072 ], dtype=float32), array([0.71057916, 0.37134275, 0.17450306, 0.52613425], dtype=float32), array([0.7184751 , 0.39082718, 0.17483431, 0.5414288 ], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32), array([0.7104702 , 0.33911332, 0.18204874, 0.5085752 ], dtype=float32), array([0.7125408 , 0.33914858, 0.18116963, 0.49774686], dtype=float32), array([0.70706934, 0.3528981 , 0.1753701 , 0.50134826], dtype=float32), array([0.70761764, 0.3546335 , 0.17554677, 0.5129982 ], dtype=float32), array([0.71186775, 0.36758322, 0.1761806 , 0.5247072 ], dtype=float32), array([0.71057916, 0.37134275, 0.17450306, 0.52613425], dtype=float32), array([0.7184751 , 0.39082718, 0.17483431, 0.5414288 ], dtype=float32), array([0.7216719 , 0.3970673 , 0.17132457, 0.54982865], dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32), array([0.7104702 , 0.33911332, 0.18204874, 0.5085752 ], dtype=float32), array([0.7125408 , 0.33914858, 0.18116963, 0.49774686], dtype=float
dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [array([0.35740668, 0.63861215, 0.10886344, 0.7260467 ], dtype=float32), array([0.3959482 , 0.6103772 , 0.12205041, 0.70955443], dtype=float32), array([0.3794309 , 0.62210834, 0.12146062, 0.7211486 ], dtype=float32), array([0.4491074 , 0.561142  , 0.15155348, 0.6802658 ], dtype=float32), array([0.46325427, 0.53464985, 0.15356275, 0.65687954], dtype=float32), array([0.51504546, 0.50230765, 0.16064581, 0.6397261 ], dtype=float32), array([0.51829135, 0.4980378 , 0.15909004, 0.6367849 ], dtype=float32), array([0.5608363, 0.4739093, 0.1651758, 0.6150805], dtype=float32), array([0.6119423 , 0.4137248 , 0.17481148, 0.570812  ], dtype=float32), array([0.6271419 , 0.39188394, 0.1784643 , 0.5502751 ], dtype=float32), array([0.70428663, 0.32984734, 0.18925282, 0.5061002 ], dtype=float32), array([0.72681713, 0.32588702, 0.18776655, 0.50180376], dtype=float32), array([0.7278029 , 0.3145944 , 0.18763399, 0.49330196], dtype=float32), array([0.7104702 , 0.33911332, 0.18204874, 0.5085752 ], dtype=float32), array([0.7125408 , 0.33914858, 0.18116963, 0.49774686], dtype=float32), array([0.70706934, 0.3528981 , 0.1753701 , 0.50134826], dtype=float32), array([0.70761764, 0.3546335 , 0.17554677, 0.5129982 ], dtype=float32), array([0.71186775, 0.36758322, 0.1761806 , 0.5247072 ], dtype=float32), array([0.71057916, 0.37134275, 0.17450306, 0.52613425], dtype=float32), array([0.7184751 , 0.39082718, 0.17483431, 0.5414288 ], dtype=float32), array([0.7216719 , 0.3970673 , 0.17132457, 0.54982865], dtype=float32), array([0.7450111 , 0.3896043 , 0.17156255, 0.5459528 ], dtype=float32), array([0.74497986, 0.38807842, 0.17354745, 0.54531723], dtype=float32), array([0.76224566, 0.3929194 , 0.17781624, 0.54530334], dtype=float32), array([0.77346957, 0.40577024, 0.1770561 , 0.54994226], dtype=float32), array([0.77779716, 0.39748016, 0.17828202, 0.54145706], dtype=float32), array([0.7923431 , 0.3864285 , 0.18346068, 0.52475345], dtype=float32), array([0.7962445 , 0.3978892 , 0.18362486, 0.52181196], dtype=float32), array([0.79926157, 0.43096507, 0.18104333, 0.52404225], dtype=float32), array([0.80051714, 0.45000443, 0.17963183, 0.52317476], dtype=float32)]

# %%
forcasted_output = np.asanyarray(forcast)
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", 'meantemp', 'humidity', 'wind_speed', 'meanpressure'
df_result.head()
# Out:
#         Date   meantemp   humidity  wind_speed  meanpressure
# 0 2017-01-01  17.692305  68.714134    4.596214   1014.336182
# 1 2017-01-02  18.953161  66.269798    5.152968   1013.814636
# 2 2017-01-03  18.412811  67.285378    5.128067   1014.181274
# 3 2017-01-04  20.692228  62.007435    6.398588   1012.888367
# 4 2017-01-05  21.155033  59.713970    6.483419   1012.148865

# %%
plt.figure(figsize=(20, 10))
plt.title('Next 30 Days')

plt.subplot(2, 2, 1)
plt.plot(df['meantemp'])
plt.plot(df_result.set_index('Date')[['meantemp']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Temp' ,fontsize=18)

plt.subplot(2, 2, 2)
plt.plot(df['humidity'])
plt.plot(df_result.set_index('Date')[['humidity']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('humidity' ,fontsize=18)

plt.subplot(2, 2, 3)
plt.plot(df['wind_speed'])
plt.plot(df_result.set_index('Date')[['wind_speed']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('wind_speed' ,fontsize=18)

plt.subplot(2, 2, 4)
plt.plot(df['meanpressure'])
plt.plot(df_result.set_index('Date')[['meanpressure']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('meanpressure' ,fontsize=18)

plt.tight_layout()
plt.show()

# %%
model2.save("temperature_forecasting_cnn_small.keras")

# %%
import pathlib

converter = tf.lite.TFLiteConverter.from_keras_model(model2)


converter.optimizations = [tf.lite.Optimize.DEFAULT]    # Uncomment this line for Model 2 and Model 3

#def representative_data_gen():                          # Uncomment the following 5 lines for Model 3
#    for input_value, _ in test_batches.take(200):
#        yield [input_value]
#converter.representative_dataset = representative_data_gen
#converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

tflite_model = converter.convert()
tflite_models_dir = pathlib.Path("")

tflite_model_file = tflite_models_dir/'cnn_small.tflite'     # Change the filename here for Model2 and Model3!
x = tflite_model_file.write_bytes(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpfl_rrerl'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 30, 4), dtype=tf.float32, name='keras_tensor_20')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   135592164219728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135592164225296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135592164226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135592164225488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135592164226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135592164226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135592164227024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135592164226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135592164227408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135592164227600: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
print(x)
# Out:
# 17440

# %%
# !pip install ai_edge_litert
# Out:
# Requirement already satisfied: ai_edge_litert in /usr/local/lib/python3.12/dist-packages (1.4.0)
# Requirement already satisfied: backports.strenum in /usr/local/lib/python3.12/dist-packages (from ai_edge_litert) (1.2.8)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from ai_edge_litert) (25.2.10)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from ai_edge_litert) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from ai_edge_litert) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ai_edge_litert) (4.14.1)

# %%
#@title Run this cell each time to test your model's accuracy (make sure to change the filename)
from tqdm import tqdm
from ai_edge_litert.interpreter import Interpreter

# Load TFLite model and allocate tensors.
tflite_model_file = '/content/cnn_small.tflite'                 # Change the filename here for Model 2 and 3
interpreter = Interpreter(model_path=tflite_model_file)
interpreter.allocate_tensors()

input_index = interpreter.get_input_details()[0]["index"]
output_index = interpreter.get_output_details()[0]["index"]

# %%
# Test the TFLite model on random input data.
input_shape = interpreter.get_input_details()[0]['shape']
output_shape = interpreter.get_output_details()[0]['shape']

# Iterate over the test data and run inference
test_predictions = []
for i in tqdm(range(len(x_test))):
    input_data = x_test[i].reshape(input_shape).astype('float32')  # Ensure input data is float32
    interpreter.set_tensor(input_index, input_data)
    interpreter.invoke()
    output_data = interpreter.get_tensor(output_index)
    test_predictions.append(output_data[0])

test_predictions = np.array(test_predictions)
test_predictions = scaler.inverse_transform(test_predictions)
# Out:
# 100%|██████████| 366/366 [00:00<00:00, 30256.92it/s]
